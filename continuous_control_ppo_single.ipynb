# %%
import math
import random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Normal

from unityagents import UnityEnvironment

print(torch.__version__)
# Out:
# 0.4.0

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h2>Use CUDA</h2>

# %%
use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# <h2>Load Reacher environment</h2>

# %%
# env = UnityEnvironment(file_name='./unity_simulation/single/Reacher.x86_64')

# %% [markdown]
# <h2>Create Environments</h2>

# %%
from multiprocessing_env import SubprocVecEnv

num_envs = 5
env_name = "./unity_simulation/single/Reacher.x86_64"

def make_env():
    def _thunk():
        env = env = UnityEnvironment(file_name=env_name)
        return env

    return _thunk

envs = [make_env() for i in range(num_envs)]
envs = SubprocVecEnv(envs)

env = gym.make(env_name)

# %% [markdown]
# <h2>Neural Network</h2>

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.normal_(m.weight, mean=0., std=0.1)
        nn.init.constant_(m.bias, 0.1)
        

class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_outputs, hidden_size, std=0.0):
        super(ActorCritic, self).__init__()
        
        self.critic = nn.Sequential(
            nn.Linear(num_inputs, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )
        
        self.actor = nn.Sequential(
            nn.Linear(num_inputs, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, num_outputs),
        )
        self.log_std = nn.Parameter(torch.ones(1, num_outputs) * std)
        
        self.apply(init_weights)
        
    def forward(self, x):
        value = self.critic(x)
        mu    = self.actor(x)
        std   = self.log_std.exp().expand_as(mu)
        dist  = Normal(mu, std)
        return dist, value

# %%
def plot(frame_idx, rewards):
    clear_output(True)
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    plt.title('frame %s. reward: %s' % (frame_idx, rewards[-1]))
    plt.plot(rewards)
    plt.show()
    
def test_env(vis=False):
    state = env.reset()
    if vis: env.render()
    done = False
    total_reward = 0
    while not done:
        state = torch.FloatTensor(state).unsqueeze(0).to(device)
        print(state)
        dist, _ = model(state)
        next_state, reward, done, _ = env.step(dist.sample().cpu().numpy()[0])
        state = next_state
        if vis: env.render()
        total_reward += reward
    return total_reward

# %%
test_env(False)
# Out:
# tensor([[ 0.9122,  0.4098,  0.1546]], device='cuda:0')
# tensor([[ 0.8995,  0.4369,  0.5975]], device='cuda:0')
# tensor([[ 0.8782,  0.4784,  0.9333]], device='cuda:0')
# tensor([[ 0.8452,  0.5344,  1.2999]], device='cuda:0')
# tensor([[ 0.7972,  0.6038,  1.6884]], device='cuda:0')
# tensor([[ 0.7277,  0.6859,  2.1526]], device='cuda:0')
# tensor([[ 0.6270,  0.7790,  2.7451]], device='cuda:0')
# tensor([[ 0.4810,  0.8767,  3.5182]], device='cuda:0')
# tensor([[ 0.2884,  0.9575,  4.1841]], device='cuda:0')
# tensor([[ 0.0434,  0.9991,  4.9842]], device='cuda:0')
# tensor([[-0.2478,  0.9688,  5.8749]], device='cuda:0')
# tensor([[-0.5564,  0.8309,  6.7932]], device='cuda:0')
# tensor([[-0.8282,  0.5605,  7.7164]], device='cuda:0')
# tensor([[-0.9815,  0.1916,  8.0000]], device='cuda:0')
# tensor([[-0.9797, -0.2007,  7.8955]], device='cuda:0')
# tensor([[-0.8262, -0.5634,  7.9294]], device='cuda:0')
# tensor([[-0.5628, -0.8266,  7.4904]], device='cuda:0')
# tensor([[-0.2517, -0.9678,  6.8673]], device='cuda:0')
# tensor([[ 0.0535, -0.9986,  6.1582]], device='cuda:0')
# tensor([[ 0.3302, -0.9439,  5.6596]], device='cuda:0')
# tensor([[ 0.5586, -0.8294,  5.1243]], device='cuda:0')
# tensor([[ 0.7390, -0.6737,  4.7778]], device='cuda:0')
# tensor([[ 0.8651, -0.5016,  4.2754]], device='cuda:0')
# tensor([[ 0.9432, -0.3322,  3.7359]], device='cuda:0')
# tensor([[ 0.9857, -0.1686,  3.3847]], device='cuda:0')
# tensor([[ 1.0000, -0.0035,  3.3172]], device='cuda:0')
# tensor([[ 0.9843,  0.1763,  3.6145]], device='cuda:0')
# tensor([[ 0.9294,  0.3690,  4.0159]], device='cuda:0')
# tensor([[ 0.8309,  0.5564,  4.2413]], device='cuda:0')
# tensor([[ 0.6690,  0.7433,  4.9586]], device='cuda:0')
# tensor([[ 0.4426,  0.8967,  5.4877]], device='cuda:0')
# tensor([[ 0.1639,  0.9865,  5.8762]], device='cuda:0')
# tensor([[-0.1711,  0.9853,  6.7309]], device='cuda:0')
# tensor([[-0.5191,  0.8547,  7.4777]], device='cuda:0')
# tensor([[-0.8137,  0.5813,  8.0000]], device='cuda:0')
# tensor([[-0.9801,  0.1985,  8.0000]], device='cuda:0')
# tensor([[-0.9753, -0.2208,  8.0000]], device='cuda:0')
# tensor([[-0.8203, -0.5719,  7.7245]], device='cuda:0')
# tensor([[-0.5639, -0.8258,  7.2573]], device='cuda:0')
# tensor([[-0.2505, -0.9681,  6.9182]], device='cuda:0')
# tensor([[ 0.0714, -0.9975,  6.4922]], device='cuda:0')
# tensor([[ 0.3533, -0.9355,  5.7931]], device='cuda:0')
# tensor([[ 0.5839, -0.8118,  5.2494]], device='cuda:0')
# tensor([[ 0.7536, -0.6574,  4.5984]], device='cuda:0')
# tensor([[ 0.8723, -0.4890,  4.1281]], device='cuda:0')
# tensor([[ 0.9519, -0.3064,  3.9913]], device='cuda:0')
# tensor([[ 0.9913, -0.1319,  3.5818]], device='cuda:0')
# tensor([[ 0.9994,  0.0355,  3.3557]], device='cuda:0')
# tensor([[ 0.9765,  0.2153,  3.6298]], device='cuda:0')
# tensor([[ 0.9181,  0.3964,  3.8112]], device='cuda:0')
# tensor([[ 0.8226,  0.5686,  3.9457]], device='cuda:0')
# tensor([[ 0.6759,  0.7370,  4.4762]], device='cuda:0')
# tensor([[ 0.4844,  0.8748,  4.7289]], device='cuda:0')
# tensor([[ 0.2384,  0.9712,  5.2997]], device='cuda:0')
# tensor([[-0.0606,  0.9982,  6.0263]], device='cuda:0')
# tensor([[-0.3934,  0.9193,  6.8756]], device='cuda:0')
# tensor([[-0.7157,  0.6984,  7.8651]], device='cuda:0')
# tensor([[-0.9429,  0.3329,  8.0000]], device='cuda:0')
# tensor([[-0.9975, -0.0705,  8.0000]], device='cuda:0')
# tensor([[-0.8881, -0.4596,  8.0000]], device='cuda:0')
# tensor([[-0.6444, -0.7647,  7.8607]], device='cuda:0')
# tensor([[-0.3286, -0.9445,  7.3094]], device='cuda:0')
# tensor([[ 0.0041, -1.0000,  6.7778]], device='cuda:0')
# tensor([[ 0.3074, -0.9516,  6.1673]], device='cuda:0')
# tensor([[ 0.5534, -0.8329,  5.4795]], device='cuda:0')
# tensor([[ 0.7348, -0.6782,  4.7795]], device='cuda:0')
# tensor([[ 0.8661, -0.4998,  4.4391]], device='cuda:0')
# tensor([[ 0.9503, -0.3114,  4.1348]], device='cuda:0')
# tensor([[ 0.9918, -0.1278,  3.7701]], device='cuda:0')
# tensor([[ 0.9977,  0.0678,  3.9204]], device='cuda:0')
# tensor([[ 0.9633,  0.2684,  4.0778]], device='cuda:0')
# tensor([[ 0.8871,  0.4615,  4.1586]], device='cuda:0')
# tensor([[ 0.7535,  0.6574,  4.7538]], device='cuda:0')
# tensor([[ 0.5534,  0.8329,  5.3388]], device='cuda:0')
# tensor([[ 0.2847,  0.9586,  5.9558]], device='cuda:0')
# tensor([[-0.0566,  0.9984,  6.9063]], device='cuda:0')
# tensor([[-0.4311,  0.9023,  7.7819]], device='cuda:0')
# tensor([[-0.7629,  0.6465,  8.0000]], device='cuda:0')
# tensor([[-0.9595,  0.2816,  8.0000]], device='cuda:0')
# tensor([[-0.9922, -0.1249,  8.0000]], device='cuda:0')
# tensor([[-0.8652, -0.5014,  8.0000]], device='cuda:0')
# tensor([[-0.6139, -0.7894,  7.6919]], device='cuda:0')
# tensor([[-0.2963, -0.9551,  7.2037]], device='cuda:0')
# tensor([[ 0.0276, -0.9996,  6.5690]], device='cuda:0')
# tensor([[ 0.3275, -0.9449,  6.1193]], device='cuda:0')
# tensor([[ 0.5678, -0.8232,  5.4037]], device='cuda:0')
# tensor([[ 0.7485, -0.6632,  4.8389]], device='cuda:0')
# tensor([[ 0.8762, -0.4820,  4.4422]], device='cuda:0')
# tensor([[ 0.9600, -0.2801,  4.3807]], device='cuda:0')
# tensor([[ 0.9964, -0.0844,  3.9880]], device='cuda:0')
# tensor([[ 0.9944,  0.1056,  3.8058]], device='cuda:0')
# tensor([[ 0.9533,  0.3019,  4.0180]], device='cuda:0')
# tensor([[ 0.8618,  0.5072,  4.5060]], device='cuda:0')
# tensor([[ 0.7147,  0.6994,  4.8518]], device='cuda:0')
# tensor([[ 0.4990,  0.8666,  5.4768]], device='cuda:0')
# tensor([[ 0.2068,  0.9784,  6.2810]], device='cuda:0')
# tensor([[-0.1507,  0.9886,  7.1934]], device='cuda:0')
# tensor([[-0.5211,  0.8535,  7.9367]], device='cuda:0')
# tensor([[-0.8329,  0.5535,  8.0000]], device='cuda:0')
# tensor([[-0.9883,  0.1528,  8.0000]], device='cuda:0')
# tensor([[-0.9683, -0.2499,  8.0000]], device='cuda:0')
# tensor([[-0.7927, -0.6097,  8.0000]], device='cuda:0')
# tensor([[-0.5180, -0.8554,  7.4133]], device='cuda:0')
# tensor([[-0.1951, -0.9808,  6.9636]], device='cuda:0')
# tensor([[ 0.1233, -0.9924,  6.3986]], device='cuda:0')
# tensor([[ 0.4071, -0.9134,  5.9137]], device='cuda:0')
# tensor([[ 0.6278, -0.7783,  5.1895]], device='cuda:0')
# tensor([[ 0.7883, -0.6153,  4.5856]], device='cuda:0')
# tensor([[ 0.8999, -0.4362,  4.2284]], device='cuda:0')
# tensor([[ 0.9693, -0.2458,  4.0598]], device='cuda:0')
# tensor([[ 0.9982, -0.0592,  3.7812]], device='cuda:0')
# tensor([[ 0.9916,  0.1294,  3.7810]], device='cuda:0')
# tensor([[ 0.9474,  0.3202,  3.9225]], device='cuda:0')
# tensor([[ 0.8591,  0.5118,  4.2276]], device='cuda:0')
# tensor([[ 0.7135,  0.7007,  4.7809]], device='cuda:0')
# tensor([[ 0.4918,  0.8707,  5.6064]], device='cuda:0')
# tensor([[ 0.1966,  0.9805,  6.3256]], device='cuda:0')
# tensor([[-0.1649,  0.9863,  7.2707]], device='cuda:0')
# tensor([[-0.5459,  0.8378,  8.0000]], device='cuda:0')
# tensor([[-0.8436,  0.5370,  8.0000]], device='cuda:0')
# tensor([[-0.9892,  0.1467,  8.0000]], device='cuda:0')
# tensor([[-0.9629, -0.2699,  8.0000]], device='cuda:0')
# tensor([[-0.7890, -0.6144,  7.7668]], device='cuda:0')
# tensor([[-0.5107, -0.8598,  7.4639]], device='cuda:0')
# tensor([[-0.1845, -0.9828,  7.0085]], device='cuda:0')
# tensor([[ 0.1348, -0.9909,  6.4143]], device='cuda:0')
# tensor([[ 0.4119, -0.9112,  5.7872]], device='cuda:0')
# tensor([[ 0.6292, -0.7772,  5.1205]], device='cuda:0')
# tensor([[ 0.7870, -0.6169,  4.5077]], device='cuda:0')
# tensor([[ 0.8962, -0.4436,  4.1047]], device='cuda:0')
# tensor([[ 0.9646, -0.2636,  3.8565]], device='cuda:0')
# tensor([[ 0.9971, -0.0762,  3.8094]], device='cuda:0')
# tensor([[ 0.9924,  0.1233,  3.9991]], device='cuda:0')
# tensor([[ 0.9444,  0.3287,  4.2258]], device='cuda:0')
# tensor([[ 0.8463,  0.5328,  4.5388]], device='cuda:0')
# tensor([[ 0.6896,  0.7242,  4.9594]], device='cuda:0')
# tensor([[ 0.4627,  0.8865,  5.5985]], device='cuda:0')
# tensor([[ 0.1667,  0.9860,  6.2713]], device='cuda:0')
# tensor([[-0.1801,  0.9836,  6.9715]], device='cuda:0')
# tensor([[-0.5493,  0.8356,  8.0000]], device='cuda:0')
# tensor([[-0.8500,  0.5268,  8.0000]], device='cuda:0')
# tensor([[-0.9907,  0.1361,  8.0000]], device='cuda:0')
# tensor([[-0.9639, -0.2664,  8.0000]], device='cuda:0')
# tensor([[-0.7875, -0.6163,  7.8879]], device='cuda:0')
# tensor([[-0.5029, -0.8644,  7.5979]], device='cuda:0')
# tensor([[-0.1729, -0.9849,  7.0632]], device='cuda:0')
# tensor([[ 0.1413, -0.9900,  6.3110]], device='cuda:0')
# tensor([[ 0.3942, -0.9190,  5.2685]], device='cuda:0')
# tensor([[ 0.5843, -0.8115,  4.3762]], device='cuda:0')
# tensor([[ 0.7280, -0.6856,  3.8277]], device='cuda:0')
# tensor([[ 0.8302, -0.5575,  3.2803]], device='cuda:0')
# tensor([[ 0.9007, -0.4345,  2.8365]], device='cuda:0')
# tensor([[ 0.9488, -0.3158,  2.5649]], device='cuda:0')
# tensor([[ 0.9791, -0.2033,  2.3305]], device='cuda:0')
# tensor([[ 0.9967, -0.0808,  2.4780]], device='cuda:0')
# tensor([[ 0.9985,  0.0548,  2.7129]], device='cuda:0')
# tensor([[ 0.9788,  0.2046,  3.0262]], device='cuda:0')
# tensor([[ 0.9349,  0.3549,  3.1346]], device='cuda:0')
# tensor([[ 0.8638,  0.5039,  3.3045]], device='cuda:0')
# tensor([[ 0.7547,  0.6561,  3.7508]], device='cuda:0')
# tensor([[ 0.5954,  0.8034,  4.3479]], device='cuda:0')
# tensor([[ 0.3833,  0.9236,  4.8885]], device='cuda:0')
# tensor([[ 0.1062,  0.9943,  5.7389]], device='cuda:0')
# tensor([[-0.2121,  0.9773,  6.4029]], device='cuda:0')
# tensor([[-0.5526,  0.8334,  7.4359]], device='cuda:0')
# tensor([[-0.8368,  0.5475,  8.0000]], device='cuda:0')
# tensor([[-0.9877,  0.1562,  8.0000]], device='cuda:0')
# tensor([[-0.9703, -0.2420,  8.0000]], device='cuda:0')
# tensor([[-0.8032, -0.5957,  7.8754]], device='cuda:0')
# tensor([[-0.5274, -0.8496,  7.5413]], device='cuda:0')
# tensor([[-0.1941, -0.9810,  7.2041]], device='cuda:0')
# tensor([[ 0.1416, -0.9899,  6.7485]], device='cuda:0')
# tensor([[ 0.4396, -0.8982,  6.2615]], device='cuda:0')
# tensor([[ 0.6813, -0.7320,  5.8878]], device='cuda:0')
# tensor([[ 0.8497, -0.5273,  5.3178]], device='cuda:0')
# tensor([[ 0.9517, -0.3071,  4.8647]], device='cuda:0')
# tensor([[ 0.9973, -0.0735,  4.7710]], device='cuda:0')
# tensor([[ 0.9848,  0.1739,  4.9683]], device='cuda:0')
# tensor([[ 0.9039,  0.4278,  5.3440]], device='cuda:0')
# tensor([[ 0.7442,  0.6679,  5.7874]], device='cuda:0')
# tensor([[ 0.4946,  0.8691,  6.4412]], device='cuda:0')
# tensor([[ 0.1668,  0.9860,  6.9960]], device='cuda:0')
# tensor([[-0.2194,  0.9756,  7.7754]], device='cuda:0')
# tensor([[-0.5966,  0.8026,  8.0000]], device='cuda:0')
# tensor([[-0.8840,  0.4675,  8.0000]], device='cuda:0')
# tensor([[-0.9983,  0.0579,  8.0000]], device='cuda:0')
# tensor([[-0.9413, -0.3375,  8.0000]], device='cuda:0')
# tensor([[-0.7383, -0.6745,  7.9218]], device='cuda:0')
# tensor([[-0.4318, -0.9020,  7.6806]], device='cuda:0')
# tensor([[-0.0899, -0.9959,  7.1285]], device='cuda:0')
# tensor([[ 0.2277, -0.9737,  6.3950]], device='cuda:0')
# tensor([[ 0.4917, -0.8708,  5.6870]], device='cuda:0')
# tensor([[ 0.6906, -0.7232,  4.9652]], device='cuda:0')
# tensor([[ 0.8364, -0.5481,  4.5671]], device='cuda:0')
# tensor([[ 0.9365, -0.3505,  4.4392]], device='cuda:0')
# tensor([[ 0.9884, -0.1519,  4.1129]], device='cuda:0')
# tensor([[ 0.9984,  0.0573,  4.1963]], device='cuda:0')
# tensor([[ 0.9626,  0.2711,  4.3442]], device='cuda:0')
# tensor([[ 0.8725,  0.4886,  4.7183]], device='cuda:0')
# tensor([[ 0.7203,  0.6936,  5.1218]], device='cuda:0')
# -1200.419962085817

# %% [markdown]
# <h2>GAE</h2>

# %%
def compute_gae(next_value, rewards, masks, values, gamma=0.99, tau=0.95):
    values = values + [next_value]
    gae = 0
    returns = []
    for step in reversed(range(len(rewards))):
        delta = rewards[step] + gamma * values[step + 1] * masks[step] - values[step]
        gae = delta + gamma * tau * masks[step] * gae
        returns.insert(0, gae + values[step])
    return returns

# %% [markdown]
# <h1> Proximal Policy Optimization Algorithm</h1>
# <h2><a href="https://arxiv.org/abs/1707.06347">Arxiv</a></h2>

# %%
def ppo_iter(mini_batch_size, states, actions, log_probs, returns, advantage):
    batch_size = states.size(0)
    for _ in range(batch_size // mini_batch_size):
        rand_ids = np.random.randint(0, batch_size, mini_batch_size)
        yield states[rand_ids, :], actions[rand_ids, :], log_probs[rand_ids, :], returns[rand_ids, :], advantage[rand_ids, :]
        
        

def ppo_update(ppo_epochs, mini_batch_size, states, actions, log_probs, returns, advantages, clip_param=0.2):
    for _ in range(ppo_epochs):
        for state, action, old_log_probs, return_, advantage in ppo_iter(mini_batch_size, states, actions, log_probs, returns, advantages):
            dist, value = model(state)
            entropy = dist.entropy().mean()
            new_log_probs = dist.log_prob(action)

            ratio = (new_log_probs - old_log_probs).exp()
            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1.0 - clip_param, 1.0 + clip_param) * advantage

            actor_loss  = - torch.min(surr1, surr2).mean()
            critic_loss = (return_ - value).pow(2).mean()

            loss = 0.5 * critic_loss + actor_loss - 0.001 * entropy

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

# %%
num_inputs  = envs.observation_space.shape[0]
num_outputs = envs.action_space.shape[0]

print(num_inputs)
print(num_outputs)

#Hyper params:
hidden_size      = 256
lr               = 3e-4
num_steps        = 20
mini_batch_size  = 5
ppo_epochs       = 4
threshold_reward = -200

model = ActorCritic(num_inputs, num_outputs, hidden_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
# Out:
# 3
# 1

# %%
max_frames = 15000
frame_idx  = 0
test_rewards = []

# %%
state = envs.reset()
early_stop = False

while frame_idx < max_frames and not early_stop:

    log_probs = []
    values    = []
    states    = []
    actions   = []
    rewards   = []
    masks     = []
    entropy = 0

    for _ in range(num_steps):
        state = torch.FloatTensor(state).to(device)
        dist, value = model(state)

        action = dist.sample()
        next_state, reward, done, _ = envs.step(action.cpu().numpy())

        log_prob = dist.log_prob(action)
        entropy += dist.entropy().mean()
        
        log_probs.append(log_prob)
        values.append(value)
        rewards.append(torch.FloatTensor(reward).unsqueeze(1).to(device))
        masks.append(torch.FloatTensor(1 - done).unsqueeze(1).to(device))
        
        states.append(state)
        actions.append(action)
        
        state = next_state
        frame_idx += 1
        
        if frame_idx % 1000 == 0:
            test_reward = np.mean([test_env() for _ in range(10)])
            test_rewards.append(test_reward)
            plot(frame_idx, test_rewards)
            if test_reward > threshold_reward: early_stop = True
            

    next_state = torch.FloatTensor(next_state).to(device)
    _, next_value = model(next_state)
    returns = compute_gae(next_value, rewards, masks, values)

    returns   = torch.cat(returns).detach()
    log_probs = torch.cat(log_probs).detach()
    values    = torch.cat(values).detach()
    states    = torch.cat(states)
    actions   = torch.cat(actions)
    advantage = returns - values
    
    ppo_update(ppo_epochs, mini_batch_size, states, actions, log_probs, returns, advantage)

# %% [markdown]
# <h1>Saving trajectories for GAIL</h1>

# %%
from itertools import count

max_expert_num = 50000
num_steps = 0
expert_traj = []

for i_episode in count():
    state = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        state = torch.FloatTensor(state).unsqueeze(0).to(device)
        dist, _ = model(state)
        action = dist.sample().cpu().numpy()[0]
        next_state, reward, done, _ = env.step(action)
        state = next_state
        total_reward += reward
        expert_traj.append(np.hstack([state, action]))
        num_steps += 1
    
    print("episode:", i_episode, "reward:", total_reward)
    
    if num_steps >= max_expert_num:
        break
        
expert_traj = np.stack(expert_traj)
print()
print(expert_traj.shape)
print()
np.save("expert_traj.npy", expert_traj)
